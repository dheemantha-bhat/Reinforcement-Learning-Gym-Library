# %%
import gpxpy
import gpxpy.gpx

import pandas as pd
import matplotlib.pyplot as plt
import geopy.distance

# %%
plt.rcParams['axes.spines.top'] = False
plt.rcParams['axes.spines.right'] = False

# %%
with open('D:/Jupyter Files Directory/faulty run.gpx', 'r') as gpx_file:
    gpx = gpxpy.parse(gpx_file)

# %%
gpx
# Out:
# GPX(tracks=[GPXTrack(name='Morning Run', segments=[GPXTrackSegment(points=[...])])])

# %%
gpx.get_track_points_no()
# Out:
# 1487

# %%
gpx.tracks[0].segments[0].points[0]
# Out:
# GPXTrackPoint(52.009513, 4.371311, elevation=1.0, time=datetime.datetime(2022, 10, 11, 5, 36, 35, tzinfo=SimpleTZ("Z")))

# %%
route_info = []

for track in gpx.tracks:
    for segment in track.segments:
        for point in segment.points:
            route_info.append({
                'latitude': point.latitude,
                'longitude': point.longitude,
                'elevation': point.elevation,
                'time':point.time
            })

# %%
route_info
# Out:
# [{'latitude': 52.009513,
#   'longitude': 4.371311,
#   'elevation': 1.0,
#   'time': datetime.datetime(2022, 10, 11, 5, 36, 35, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.009499,
#   'longitude': 4.371282,
#   'elevation': 1.0,
#   'time': datetime.datetime(2022, 10, 11, 5, 36, 36, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.009501,
#   'longitude': 4.371266,
#   'elevation': 1.0,
#   'time': datetime.datetime(2022, 10, 11, 5, 36, 37, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.009503,
#   'longitude': 4.37125,
#   'elevation': 1.0,
#   'time': datetime.datetime(2022, 10, 11, 5, 36, 38, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.009526,
#   'longitude': 4.371225,
#   'elevation': 1.0,
#   'time': datetime.datetime(2022, 10, 11, 5, 36, 40, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.00954,
#   'longitude': 4.371213,
#   'elevation': 1.0,
#   'time': datetime.datetime(2022, 10, 11, 5, 36, 41, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.009547,
#   'longitude': 4.371187,
#   'elevation': 1.0,
#   'time': datetime.datetime(2022, 10, 11, 5, 36, 42, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.009557,
#   'longitude': 4.371164,
#   'elevation': 1.0,
#   'time': datetime.datetime(2022, 10, 11, 5, 36, 43, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.009526,
#   'longitude': 4.371018,
#   'elevation': 0.9,
#   'time': datetime.datetime(2022, 10, 11, 5, 36, 45, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.009525,
#   'longitude': 4.370965,
#   'elevation': 0.9,
#   'time': datetime.datetime(2022, 10, 11, 5, 36, 46, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.009527,
#   'longitude': 4.370954,
#   'elevation': 0.9,
#   'time': datetime.datetime(2022, 10, 11, 5, 36, 47, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.009539,
#   'longitude': 4.370944,
#   'elevation': 0.9,
#   'time': datetime.datetime(2022, 10, 11, 5, 36, 48, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.009542,
#   'longitude': 4.370914,
#   'elevation': 0.9,
#   'time': datetime.datetime(2022, 10, 11, 5, 36, 49, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.00954,
#   'longitude': 4.370857,
#   'elevation': 0.9,
#   'time': datetime.datetime(2022, 10, 11, 5, 36, 50, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.009541,
#   'longitude': 4.37081,
#   'elevation': 0.9,
#   'time': datetime.datetime(2022, 10, 11, 5, 36, 52, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.009541,
#   'longitude': 4.370759,
#   'elevation': 0.9,
#   'time': datetime.datetime(2022, 10, 11, 5, 36, 53, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.009537,
#   'longitude': 4.370707,
#   'elevation': 0.9,
#   'time': datetime.datetime(2022, 10, 11, 5, 36, 54, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.009532,
#   'longitude': 4.370654,
#   'elevation': 0.9,
#   'time': datetime.datetime(2022, 10, 11, 5, 36, 55, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.009529,
#   'longitude': 4.370609,
#   'elevation': 0.9,
#   'time': datetime.datetime(2022, 10, 11, 5, 36, 56, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.009532,
#   'longitude': 4.370553,
#   'elevation': 0.9,
#   'time': datetime.datetime(2022, 10, 11, 5, 36, 57, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.009547,
#   'longitude': 4.370439,
#   'elevation': 0.9,
#   'time': datetime.datetime(2022, 10, 11, 5, 36, 59, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.009546,
#   'longitude': 4.370393,
#   'elevation': 0.9,
#   'time': datetime.datetime(2022, 10, 11, 5, 37, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.00956,
#   'longitude': 4.370351,
#   'elevation': 0.9,
#   'time': datetime.datetime(2022, 10, 11, 5, 37, 1, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.009558,
#   'longitude': 4.370326,
#   'elevation': 0.9,
#   'time': datetime.datetime(2022, 10, 11, 5, 37, 3, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.009555,
#   'longitude': 4.370301,
#   'elevation': 0.9,
#   'time': datetime.datetime(2022, 10, 11, 5, 37, 4, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.009553,
#   'longitude': 4.370275,
#   'elevation': 0.9,
#   'time': datetime.datetime(2022, 10, 11, 5, 37, 5, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.009551,
#   'longitude': 4.37023,
#   'elevation': 0.9,
#   'time': datetime.datetime(2022, 10, 11, 5, 37, 6, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.009549,
#   'longitude': 4.370175,
#   'elevation': 0.9,
#   'time': datetime.datetime(2022, 10, 11, 5, 37, 7, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.009561,
#   'longitude': 4.370114,
#   'elevation': 1.0,
#   'time': datetime.datetime(2022, 10, 11, 5, 37, 8, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.009566,
#   'longitude': 4.370089,
#   'elevation': 1.0,
#   'time': datetime.datetime(2022, 10, 11, 5, 37, 9, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.009561,
#   'longitude': 4.370013,
#   'elevation': 1.0,
#   'time': datetime.datetime(2022, 10, 11, 5, 37, 11, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.009555,
#   'longitude': 4.36994,
#   'elevation': 1.0,
#   'time': datetime.datetime(2022, 10, 11, 5, 37, 12, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.009542,
#   'longitude': 4.369866,
#   'elevation': 1.1,
#   'time': datetime.datetime(2022, 10, 11, 5, 37, 14, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.00954,
#   'longitude': 4.36984,
#   'elevation': 1.1,
#   'time': datetime.datetime(2022, 10, 11, 5, 37, 15, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.009538,
#   'longitude': 4.369813,
#   'elevation': 1.1,
#   'time': datetime.datetime(2022, 10, 11, 5, 37, 16, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.009545,
#   'longitude': 4.369751,
#   'elevation': 1.1,
#   'time': datetime.datetime(2022, 10, 11, 5, 37, 17, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.009547,
#   'longitude': 4.369725,
#   'elevation': 1.1,
#   'time': datetime.datetime(2022, 10, 11, 5, 37, 18, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.009546,
#   'longitude': 4.369677,
#   'elevation': 1.2,
#   'time': datetime.datetime(2022, 10, 11, 5, 37, 20, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.009548,
#   'longitude': 4.369623,
#   'elevation': 1.2,
#   'time': datetime.datetime(2022, 10, 11, 5, 37, 21, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.009568,
#   'longitude': 4.369579,
#   'elevation': 1.2,
#   'time': datetime.datetime(2022, 10, 11, 5, 37, 22, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.009578,
#   'longitude': 4.369572,
#   'elevation': 1.2,
#   'time': datetime.datetime(2022, 10, 11, 5, 37, 23, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.009595,
#   'longitude': 4.369536,
#   'elevation': 1.3,
#   'time': datetime.datetime(2022, 10, 11, 5, 37, 25, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.009633,
#   'longitude': 4.369511,
#   'elevation': 1.3,
#   'time': datetime.datetime(2022, 10, 11, 5, 37, 26, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.009686,
#   'longitude': 4.369562,
#   'elevation': 1.3,
#   'time': datetime.datetime(2022, 10, 11, 5, 37, 27, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.009721,
#   'longitude': 4.369577,
#   'elevation': 1.3,
#   'time': datetime.datetime(2022, 10, 11, 5, 37, 28, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.00975,
#   'longitude': 4.369578,
#   'elevation': 1.3,
#   'time': datetime.datetime(2022, 10, 11, 5, 37, 29, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.009787,
#   'longitude': 4.36957,
#   'elevation': 1.3,
#   'time': datetime.datetime(2022, 10, 11, 5, 37, 30, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.009815,
#   'longitude': 4.369557,
#   'elevation': 1.3,
#   'time': datetime.datetime(2022, 10, 11, 5, 37, 31, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.009821,
#   'longitude': 4.369549,
#   'elevation': 1.3,
#   'time': datetime.datetime(2022, 10, 11, 5, 37, 33, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.009828,
#   'longitude': 4.369541,
#   'elevation': 1.3,
#   'time': datetime.datetime(2022, 10, 11, 5, 37, 34, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.009871,
#   'longitude': 4.369534,
#   'elevation': 1.3,
#   'time': datetime.datetime(2022, 10, 11, 5, 37, 35, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.

#   'time': datetime.datetime(2022, 10, 11, 5, 57, 45, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.00799,
#   'longitude': 4.359925,
#   'elevation': 2.6,
#   'time': datetime.datetime(2022, 10, 11, 5, 57, 47, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.007958,
#   'longitude': 4.359941,
#   'elevation': 2.6,
#   'time': datetime.datetime(2022, 10, 11, 5, 57, 48, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.007926,
#   'longitude': 4.359957,
#   'elevation': 2.6,
#   'time': datetime.datetime(2022, 10, 11, 5, 57, 49, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.007949,
#   'longitude': 4.359924,
#   'elevation': 2.6,
#   'time': datetime.datetime(2022, 10, 11, 5, 57, 51, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.007955,
#   'longitude': 4.359922,
#   'elevation': 2.6,
#   'time': datetime.datetime(2022, 10, 11, 5, 57, 52, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.007982,
#   'longitude': 4.359924,
#   'elevation': 2.5,
#   'time': datetime.datetime(2022, 10, 11, 5, 57, 53, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.00806,
#   'longitude': 4.359878,
#   'elevation': 2.5,
#   'time': datetime.datetime(2022, 10, 11, 5, 57, 54, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.008128,
#   'longitude': 4.359844,
#   'elevation': 2.4,
#   'time': datetime.datetime(2022, 10, 11, 5, 57, 55, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.008265,
#   'longitude': 4.359789,
#   'elevation': 2.3,
#   'time': datetime.datetime(2022, 10, 11, 5, 58, 1, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.00833,
#   'longitude': 4.359766,
#   'elevation': 2.3,
#   'time': datetime.datetime(2022, 10, 11, 5, 58, 2, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.0083,
#   'longitude': 4.359778,
#   'elevation': 2.3,
#   'time': datetime.datetime(2022, 10, 11, 5, 58, 4, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.008288,
#   'longitude': 4.359774,
#   'elevation': 2.3,
#   'time': datetime.datetime(2022, 10, 11, 5, 58, 5, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.008294,
#   'longitude': 4.359774,
#   'elevation': 2.3,
#   'time': datetime.datetime(2022, 10, 11, 5, 58, 6, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.008297,
#   'longitude': 4.359762,
#   'elevation': 2.3,
#   'time': datetime.datetime(2022, 10, 11, 5, 58, 7, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.008322,
#   'longitude': 4.359744,
#   'elevation': 2.3,
#   'time': datetime.datetime(2022, 10, 11, 5, 58, 8, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.008362,
#   'longitude': 4.359731,
#   'elevation': 2.3,
#   'time': datetime.datetime(2022, 10, 11, 5, 58, 9, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.008376,
#   'longitude': 4.359723,
#   'elevation': 2.3,
#   'time': datetime.datetime(2022, 10, 11, 5, 58, 15, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.008389,
#   'longitude': 4.359715,
#   'elevation': 2.3,
#   'time': datetime.datetime(2022, 10, 11, 5, 58, 17, tzinfo=SimpleTZ("Z"))},
#  {'latitude': 52.008403,
#   'longitude': 4.359708,
#   'elevation': 2.3,
#   'time': datetime.datetime(2022, 10, 11, 5, 58, 19, tzinfo=SimpleTZ("Z"))},
#  ...]

# %%
route_df = pd.DataFrame(route_info)
route_df[:5]
# Out:
#     latitude  longitude  elevation                      time
# 0  52.009513   4.371311        1.0 2022-10-11 05:36:35+00:00
# 1  52.009499   4.371282        1.0 2022-10-11 05:36:36+00:00
# 2  52.009501   4.371266        1.0 2022-10-11 05:36:37+00:00
# 3  52.009503   4.371250        1.0 2022-10-11 05:36:38+00:00
# 4  52.009526   4.371225        1.0 2022-10-11 05:36:40+00:00

# %%
plt.figure(figsize=(7, 4))
plt.scatter(route_df['longitude'], route_df['latitude'])
plt.title('Latitude and longitude points', size=15);

# %%
dist_list=[0]
time_list=[0]
for i in range(1,1487):
    coord1=(route_df.iloc[i-1,0],route_df.iloc[i-1,1])
    coord2=(route_df.iloc[i,0],route_df.iloc[i,1])
    dist=geopy.distance.geodesic(coord1, coord2).m
    dist_list.append(dist)
    time_list.append((route_df.iloc[i,3]-route_df.iloc[i-1,3]).total_seconds())
    
    
    
route_df['time_sec']=time_list    
route_df['distance']=   dist_list
route_df['speed']=route_df['distance']/route_df['time_sec']
route_df['distance'] = route_df['distance'].fillna(0)
route_df['speed'] = route_df['speed'].fillna(0)

# %%
route_df.head()
# Out:
#     latitude  longitude  elevation                      time  time_sec  \
# 0  52.009513   4.371311        1.0 2022-10-11 05:36:35+00:00       0.0
# 1  52.009499   4.371282        1.0 2022-10-11 05:36:36+00:00       1.0
# 2  52.009501   4.371266        1.0 2022-10-11 05:36:37+00:00       1.0
# 3  52.009503   4.371250        1.0 2022-10-11 05:36:38+00:00       1.0
# 4  52.009526   4.371225        1.0 2022-10-11 05:36:40+00:00       2.0
#
#    distance     speed
# 0  0.000000  0.000000
# 1  2.528163  2.528163
# 2  1.120927  1.120927
# 3  1.120927  1.120927
# 4  3.081547  1.540774

# %%
sum(route_df['distance'])/1000
# Out:
# 6.602401315184216

# %% [markdown]
# GPX says that I ran 6.6km. But in reality it was 4.91 km.

# %% [markdown]
# My pace for the run was not more than  5:50min/km.

# %% [markdown]
# So that is not more than 2.86m/s.

# %% [markdown]
# So this function removes speed more than the specified speed and gives the dataframe with the remaining lat-lons.

# %%
def clean_gpx(speed):
    route_clean1_df=route_df.loc[(route_df["speed"] < speed)].reset_index(drop=True)
    dist_list=[0]
    time_list=[0]
    for i in range(1,631):
        coord1=(route_clean1_df.iloc[i-1,0],route_clean1_df.iloc[i-1,1])
        coord2=(route_clean1_df.iloc[i,0],route_clean1_df.iloc[i,1])
        dist=geopy.distance.geodesic(coord1, coord2).m
        dist_list.append(dist)
        time_list.append((route_clean1_df.iloc[i,3]-route_clean1_df.iloc[i-1,3]).total_seconds())
    route_clean1_df['time_sec_clean']=time_list    
    route_clean1_df['distance_clean']=dist_list

    route_clean1_df['time_sec_clean'] = route_clean1_df['time_sec_clean'].fillna(0)
    route_clean1_df['distance_clean'] = route_clean1_df['distance_clean'].fillna(0)

    
    return route_clean1_df

# %%
clean_gpx(2.86)
# Out:
#       latitude  longitude  elevation                      time  time_sec  \
# 0    52.009513   4.371311        1.0 2022-10-11 05:36:35+00:00       0.0
# 1    52.009499   4.371282        1.0 2022-10-11 05:36:36+00:00       1.0
# 2    52.009501   4.371266        1.0 2022-10-11 05:36:37+00:00       1.0
# 3    52.009503   4.371250        1.0 2022-10-11 05:36:38+00:00       1.0
# 4    52.009526   4.371225        1.0 2022-10-11 05:36:40+00:00       2.0
# ..         ...        ...        ...                       ...       ...
# 626  52.009552   4.370486        0.9 2022-10-11 06:07:59+00:00       2.0
# 627  52.009545   4.370440        0.9 2022-10-11 06:08:01+00:00       2.0
# 628  52.009520   4.370836        0.9 2022-10-11 06:08:08+00:00       2.0
# 629  52.009519   4.370884        0.9 2022-10-11 06:08:10+00:00       1.0
# 630  52.009522   4.370851        0.9 2022-10-11 06:08:11+00:00       1.0
#
#      distance     speed  time_sec_clean  distance_clean
# 0    0.000000  0.000000             0.0        0.000000
# 1    2.528163  2.528163             1.0        2.528163
# 2    1.120927  1.120927             1.0        1.120927
# 3    1.120927  1.120927             1.0        1.120927
# 4    3.081547  1.540774             2.0        3.081547
# ..        ...       ...             ...             ...
# 626  5.533492  2.766746             2.0        5.533492
# 627  3.253132  1.626566             2.0        3.253132
# 628  3.988692  1.994346             7.0       27.332634
# 629  0.360898  0.360898             2.0        3.297723
# 630  2.290349  2.290349             1.0        2.290349
#
# [631 rows x 9 columns]

# %%
sum(clean_gpx(2.86)['distance_clean'])/1000
# Out:
# 5.37848288272255

# %% [markdown]
# The cleaning of error prone lat-lons has reduced the distance closer toward reality.

# %% [markdown]
# The original GPX has a error of 34%. The modified GPX has a error of 9%.

# %%
plt.figure(figsize=(7, 4))
plt.scatter(route_clean1_df['longitude'], route_clean1_df['latitude'])
plt.title('Latitude and longitude points', size=15);
